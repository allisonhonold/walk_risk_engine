# %% [markdown]
# # Initial Exploratory Data Analysis

# %% [markdown]
# ## Load necessary packages

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Helper functions

# %%
def expand_date(dataframe):
    """expands the date to add columns with year, month, day, weekday
    
    Args:
        dataframe: a pandas dataframe with column 'date', among others
    
    Returns:
        a copy of the dataframe with out the date column, and with the
            new year, month, day, weekday columns
    """
    df_copy = dataframe.copy()
    X = pd.to_datetime(df_copy['date'], format="%Y-%m-%d")
    df_copy['year'] = [x.year for x in X]
    df_copy['month'] = [x.month for x in X]
    df_copy['day'] = [x.day for x in X]
    df_copy['weekday'] = [x.weekday() for x in X]
    df_copy = df_copy.drop(columns=['date'])
    print(df_copy.head())
    return df_copy

# %%
def plot_w_best_fit_line(x, y):
    """plots two-dimensional data with a dashed best fit line.
    
    Args:
        x: x-values
        y: y-values
        
    Returns:
        none
    """
    coef = np.polyfit(x,y,1)
    poly1d_fn = np.poly1d(coef) 
    # poly1d_fn is now a function which takes in x and returns an estimate for y

    plt.plot(x,y, 'yo', x, poly1d_fn(x), '--k')

# %% [markdown]
# ## Load data from SQL database

# %%
df = pd.read_sql_table('manhattan_loc_d_ar_wea', 'postgresql:///walk')

# %% [markdown]
# ## Data Cleaning

# %%
# fill n_arrests with 0 in place of NaN
df['n_arrests'] = df['n_arrests'].fillna(value=0).astype(int)

# %%
# expand date features
df_expanded = expand_date(df)
# Out:
#    latitude  longitude  n_arrests  ap_t_high100  ap_t_low100  cloud  humidity  \
# 0    40.683    -74.023          0          3974         3626     95        82
# 1    40.684    -74.012          0          3974         3626     95        82
# 2    40.684    -74.024          0          3974         3626     95        82
# 3    40.685    -74.022          0          3974         3626     95        82
# 4    40.685    -74.023          0          3974         3626     95        82
#
#    precip_inten_max10000  precip_proba100  sunriseTime  sunsetTime  \
# 0                     17               13   1136118060  1136151594
# 1                     17               13   1136118060  1136151594
# 2                     17               13   1136118060  1136151594
# 3                     17               13   1136118060  1136151594
# 4                     17               13   1136118060  1136151594
#
#    wind_gust100  precip_accum100  year  month  day  weekday
# 0           454              NaN  2006      1    1        6
# 1           454              NaN  2006      1    1        6
# 2           454              NaN  2006      1    1        6
# 3           454              NaN  2006      1    1        6
# 4           454              NaN  2006      1    1        6

# %%
# ozone levels were not recorded for the earlier years of the data set
# they do not seem to be correlated with the arrest count
# decided to drop ozone readings.
# df_expanded = df_expanded.drop(columns=['ozone10'])

# the remaining features all have NaN in place of zero. Filling NaNs with 0s
df_expanded.fillna(0)
# Out:
#           latitude  longitude  n_arrests  ap_t_high100  ap_t_low100  cloud  \
# 0           40.683    -74.023          0          3974         3626     95
# 1           40.684    -74.012          0          3974         3626     95
# 2           40.684    -74.024          0          3974         3626     95
# 3           40.685    -74.022          0          3974         3626     95
# 4           40.685    -74.023          0          3974         3626     95
# ...            ...        ...        ...           ...          ...    ...
# 31111843    40.878    -73.909          0          8357         6475     37
# 31111844    40.878    -73.910          0          8357         6475     37
# 31111845    40.878    -73.911          0          8357         6475     37
# 31111846    40.878    -73.912          0          8357         6475     37
# 31111847    40.879    -73.911          0          8357         6475     37
#
#           humidity  precip_inten_max10000  precip_proba100  sunriseTime  \
# 0               82                     17               13   1136118060
# 1               82                     17               13   1136118060
# 2               82                     17               13   1136118060
# 3               82                     17               13   1136118060
# 4               82                     17               13   1136118060
# ...            ...                    ...              ...          ...
# 31111843        58                     39               29   1561886932
# 31111844        58                     39               29   1561886932
# 31111845        58                     39               29   1561886932
# 31111846        58                     39               29   1561886932
# 31111847        58                     39               29   1561886932
#
#           sunsetTime  wind_gust100  precip_accum100  year  month  day  weekday
# 0         1136151594           454              0.0  2006      1    1        6
# 1         1136151594           454              0.0  2006      1    1        6
# 2         1136151594           454              0.0  2006      1    1        6
# 3         1136151594           454              0.0  2006      1    1        6
# 4         1136151594           454              0.0  2006      1    1        6
# ...              ...           ...              ...   ...    ...  ...      ...
# 31111843  1561941130          1425              0.0  2019      6   30        6
# 31111844  1561941130          1425              0.0  2019      6   30        6
# 31111845  1561941130          1425              0.0  2019      6   30        6
# 31111846  1561941130          1425              0.0  2019      6   30        6
# 31111847  1561941130          1425              0.0  2019      6   30        6
#
# [31111848 rows x 17 columns]

# %%
from statsmodels.formula.api import ols

# %% [markdown]
# ## Looking at single-feature linear regression for each feature

# %%
for col in df_expanded.columns:
    outcome = 'n_arrests'
    predictor = col
    formula = outcome + '~' + predictor
    model = ols(formula=formula, data=df_expanded).fit()
    print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              n_arrests   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     217.3
# Date:                Tue, 26 Nov 2019   Prob (F-statistic):           3.53e-49
# Time:                        13:59:26   Log-Likelihood:            -9.0778e+06
# No. Observations:            31111848   AIC:                         1.816e+07
# Df Residuals:                31111846   BIC:                         1.816e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.8245      0.053     15.537      0.000       0.721       0.929
# latitude      -0.0192      0.001    -14.741      0.000      -0.022      -0.017
# ==============================================================================
# Omnibus:                 82149601.520   Durbin-Watson:                   1.888
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   49748739311822.367
# Skew:                          29.983   Prob(JB):                         0.00
# Kurtosis:                    6197.602   Cond. No.                     3.73e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.73e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              n_arrests   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     55.80
# Date:                Tue, 26 Nov 2019   Prob (F-statistic):           8.04e-14
# Time:                        14:00:18   Log-Likelihood:            -9.0779e+06
# No. Observations:            31111848   AIC:                         1.816e+07
# Df Residuals:                31111846   BIC:                         1.816e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.1467      0.159     -7.204      0.000      -1.459      -0.835
# longitude     -0.0161      0.002     -7.470      0.000      -0.020      -0.012
# ==============================================================================
# Omnibus:                 82150021.706   Durbin-Watson:                   1.888
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   49749738241854.789
# Skew:                          29.984   Prob(JB):                         0.00
# Kurtosis:                    6197.664   Cond. No.                     2.03e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.03e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              n_arrests   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.504e+28
# Date:                Tue, 26 Nov 2019   Prob (F-statistic):               0.00
# Time:                        14:00:49   Log-Likelihood:             7.3181e+08
# No. Observations:            31111848   AIC:                        -1.464e+09
# Df Residuals:                31111846   BIC:                        -1.464e+09
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1.911e-12   2.66e-15   -717.338      0.000   -1.92e-12   -1.91e-12
# n_arrests      1.0000   8.15e-15   1.23e+14      0.000       1.000       1.000
# ==============================================================================
# Omnibus:                 82150604.721   Durbin-Watson:                   1.888
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   49751579151388.656
# Skew:                         -29.984   Prob(JB):                         0.00
# Kurtosis:                    6197.779   Cond. No.                         3.09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              n_arrests   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     156.8
# Date:                Tue, 26 Nov 2019   Prob (F-statistic):           5.80e-36
# Time:                        14:01:23   Log-Likelihood:            -9.0779e+06
# No. Observations:            31111848   AIC:                         1.816e+07
# Df Residuals:                31111846   BIC:                         1.816e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        0.0401      0.000    221.750      0.000       0.040       0.040
# ap_t_high100  3.521e-07   2.81e-08     12.520      0.000    2.97e-07    4.07e-07
# ==============================================================================
# Omnibus:                 82150738.373   Durbin-Watson:                   1.888
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   49751636540922.109
# Skew:                          29.984   Prob(JB):                         0.00
# Kurtosis:                    6197.782   Cond. No.                     2.00e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large,  2e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              n_arrests   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     79.67
# Date:                Tue, 26 Nov 2019   Prob (F-statistic):           4.42e-19
# Time:                        14:02:02   Log-Likelihood:            -9.0779e+06
# No. Observations:            31111848   AIC:                         1.816e+07
# Df Residuals:                31111846   BIC:                         1.816e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.0410      0.000    261.536      0.000       0.041       0.041
# ap_t_low100  2.757e-07   3.09e-08      8.926      0.000    2.15e-07    3.36e-07
# ==============================================================================
# Omnibus:                 82150635.068   Durbin-Watson:                   1.888
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   49751197889553.523
# Skew:                          29.984   Prob(JB):                         0.00
# Kurtosis:                    6197.755   Cond. No.                     1.37e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.37e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              n_arrests   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     212.3
# Date:                Tue, 26 Nov 2019   Prob (F-statistic):           4.25e-48
# Time:                        14:02:34   Log-Likelihood:            -9.0778e+06
# No. Observations:            31111848   AIC:                         1.816e+07
# Df Residuals:                31111846   BIC:                         1.816e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0437      0.000    387.241      0.000       0.043       0.044
# cloud      -2.864e-05   1.97e-06    -14.572      0.000   -3.25e-05   -2.48e-05
# ==============================================================================
# Omnibus:                 82150949.060   Durbin-Watson:                   1.888
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   49754278401668.242
# Skew:                          29.985   Prob(JB):                         0.00
# Kurtosis:                    6197.947   Cond. No.                         111.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              n_arrests   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     292.8
# Date:                Tue, 26 Nov 2019   Prob (F-statistic):           1.25e-65
# Time:                        14:03:11   Log-Likelihood:            -9.0778e+06
# No. Observations:            31111848   AIC:                         1.816e+07
# Df Residuals:                31111846   BIC:                         1.816e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0469      0.000    169.247      0.000       0.046       0.047
# humidity   -6.978e-05   4.08e-06    -17.110      0.000   -7.78e-05   -6.18e-05
# ==============================================================================
# Omnibus:                 82150943.891   Durbin-Watson:                   1.888
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   49754412587136.242
# Skew:                          29.985   Prob(JB):                         0.00
# Kurtosis:                    6197.955   Cond. No.                         324.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              n_arrests   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     456.7
# Date:                Tue, 26 Nov 2019   Prob (F-statistic):          2.52e-101
# Time:                        14:03:46   Log-Likelihood:            -9.0777e+06
# No. Observations:            31111848   AIC:                         1.816e+07
# Df Residuals:                31111846   BIC:                         1.816e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 0.0428   6.28e-05    681.197      0.000       0.043       0.043
# precip_inten_max10000 -2.237e-06   1.05e-07    -21.371      0.000   -2.44e-06   -2.03e-06
# ==============================================================================
# Omnibus:                 82150987.439   Durbin-Watson:                   1.888
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   49754722468638.617
# Skew:                          29.985   Prob(JB):                         0.00
# Kurtosis:                    6197.975   Cond. No.                         648.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              n_arrests   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     588.7
# Date:                Tue, 26 Nov 2019   Prob (F-statistic):          4.79e-130
# Time:                        14:04:22   Log-Likelihood:            -9.0776e+06
# No. Observations:            31111848   AIC:                         1.816e+07
# Df Residuals:                31111846   BIC:                         1.816e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           0.0433    7.2e-05    601.317      0.000       0.043       0.043
# precip_proba100 -3.524e-05   1.45e-06    -24.263      0.000   -3.81e-05   -3.24e-05
# ==============================================================================
# Omnibus:                 82151314.563   Durbin-Watson:                   1.888
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   49757215927787.383
# Skew:                          29.985   Prob(JB):                         0.00
# Kurtosis:                    6198.130   Cond. No.                         61.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              n_arrests   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                 1.059e+04
# Date:                Tue, 26 Nov 2019   Prob (F-statistic):               0.00
# Time:                        14:04:59   Log-Likelihood:            -9.0726e+06
# No. Observations:            31111848   AIC:                         1.815e+07
# Df Residuals:                31111846   BIC:                         1.815e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.1078      0.001    168.510      0.000       0.107       0.109
# sunriseTime  -4.86e-11   4.72e-13   -102.891      0.000   -4.95e-11   -4.77e-11
# ==============================================================================
# Omnibus:                 82160246.566   Durbin-Watson:                   1.889
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   49818703100404.672
# Skew:                          29.993   Prob(JB):                         0.00
# Kurtosis:                    6201.957   Cond. No.                     1.49e+10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.49e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              n_arrests   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                 1.059e+04
# Date:                Tue, 26 Nov 2019   Prob (F-statistic):               0.00
# Time:                        14:05:34   Log-Likelihood:            -9.0726e+06
# No. Observations:            31111848   AIC:                         1.815e+07
# Df Residuals:                31111846   BIC:                         1.815e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.1078      0.001    168.507      0.000       0.107       0.109
# sunsetTime  -4.86e-11   4.72e-13   -102.890      0.000   -4.95e-11   -4.77e-11
# ==============================================================================
# Omnibus:                 82160246.337   Durbin-Watson:                   1.889
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   49818701744467.695
# Skew:                          29.993   Prob(JB):                         0.00
# Kurtosis:                    6201.956   Cond. No.                     1.49e+10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.49e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              n_arrests   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     6.792
# Date:                Tue, 26 Nov 2019   Prob (F-statistic):            0.00916
# Time:                        14:06:15   Log-Likelihood:            -9.0779e+06
# No. Observations:            31111848   AIC:                         1.816e+07
# Df Residuals:                31111846   BIC:                         1.816e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        0.0426      0.000    279.299      0.000       0.042       0.043
# wind_gust100 -2.954e-07   1.13e-07     -2.606      0.009   -5.17e-07   -7.32e-08
# ==============================================================================
# Omnibus:                 82150537.701   Durbin-Watson:                   1.888
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   49751070483280.797
# Skew:                          29.984   Prob(JB):                         0.00
# Kurtosis:                    6197.747   Cond. No.                     3.54e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.54e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              n_arrests   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     80.10
# Date:                Tue, 26 Nov 2019   Prob (F-statistic):           3.57e-19
# Time:                        14:06:27   Log-Likelihood:            -1.8277e+05
# No. Observations:              883680   AIC:                         3.655e+05
# Df Residuals:                  883678   BIC:                         3.656e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           0.0382      0.000    106.582      0.000       0.037       0.039
# precip_accum100 -3.765e-05   4.21e-06     -8.950      0.000   -4.59e-05   -2.94e-05
# ==============================================================================
# Omnibus:                  1737471.707   Durbin-Watson:                   1.871
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       7183550648.635
# Skew:                          15.656   Prob(JB):                         0.00
# Kurtosis:                     443.589   Cond. No.                         96.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              n_arrests   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                 1.014e+04
# Date:                Tue, 26 Nov 2019   Prob (F-statistic):               0.00
# Time:                        14:07:02   Log-Likelihood:            -9.0729e+06
# No. Observations:            31111848   AIC:                         1.815e+07
# Df Residuals:                31111846   BIC:                         1.815e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.0593      0.030    102.132      0.000       3.001       3.118
# year          -0.0015   1.49e-05   -100.722      0.000      -0.002      -0.001
# ==============================================================================
# Omnibus:                 82159798.438   Durbin-Watson:                   1.889
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   49815030958373.484
# Skew:                          29.993   Prob(JB):                         0.00
# Kurtosis:                    6201.728   Cond. No.                     1.04e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.04e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              n_arrests   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     660.4
# Date:                Tue, 26 Nov 2019   Prob (F-statistic):          1.22e-145
# Time:                        14:08:06   Log-Likelihood:            -9.0776e+06
# No. Observations:            31111848   AIC:                         1.816e+07
# Df Residuals:                31111846   BIC:                         1.816e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0450      0.000    367.170      0.000       0.045       0.045
# month         -0.0004   1.68e-05    -25.698      0.000      -0.000      -0.000
# ==============================================================================
# Omnibus:                 82151363.604   Durbin-Watson:                   1.888
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   49758635319949.805
# Skew:                          29.985   Prob(JB):                         0.00
# Kurtosis:                    6198.218   Cond. No.                         15.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              n_arrests   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     471.9
# Date:                Tue, 26 Nov 2019   Prob (F-statistic):          1.23e-104
# Time:                        14:08:57   Log-Likelihood:            -9.0777e+06
# No. Observations:            31111848   AIC:                         1.816e+07
# Df Residuals:                31111846   BIC:                         1.816e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0445      0.000    374.210      0.000       0.044       0.045
# day           -0.0001    6.6e-06    -21.724      0.000      -0.000      -0.000
# ==============================================================================
# Omnibus:                 82150349.706   Durbin-Watson:                   1.888
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   49750665763452.625
# Skew:                          29.984   Prob(JB):                         0.00
# Kurtosis:                    6197.722   Cond. No.                         37.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              n_arrests   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1415.
# Date:                Tue, 26 Nov 2019   Prob (F-statistic):          1.15e-309
# Time:                        14:09:43   Log-Likelihood:            -9.0772e+06
# No. Observations:            31111848   AIC:                         1.815e+07
# Df Residuals:                31111846   BIC:                         1.815e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0455      0.000    434.878      0.000       0.045       0.046
# weekday       -0.0011    2.9e-05    -37.617      0.000      -0.001      -0.001
# ==============================================================================
# Omnibus:                 82151050.588   Durbin-Watson:                   1.889
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   49760580652129.211
# Skew:                          29.985   Prob(JB):                         0.00
# Kurtosis:                    6198.339   Cond. No.                         6.86
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
