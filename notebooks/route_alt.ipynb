# %%
# load necessary modules
from results import get_backend_results
import folium

# %%
# set start and end points
start_lat = '40.70754571118274'
start_long = '-74.01065249755857'
end_lat = '40.79701564162565'
end_long = '-73.96731544946289'

m, risk, warning = get_backend_results(start_lat, start_long, end_lat, end_long)
m
# Out:
# 200 OK
# ...

# %%
risk_rating
# Out:
# (1, 'low')
